# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import random

# %%
filepath='C:/Users/shaha/Desktop/Springboard/DataScience_Capstone2/Dataset_II/Hotel booking/hotel_bookings.csv'
dfi=pd.read_csv(filepath)

# %%
dfi
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
print(dfi.shape)
dfi.columns
# Out:
# (119390, 32)
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
dfi.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
dfi
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dfi.count().isna()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                          False
# babies                            False
# meal                              False
# country                           False
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# ...

# %%
dfi.isna()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of company doesn't have a name
dfi[dfi['company'].isna()==True]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of company has a name
dfi[dfi['company'].isna()==False]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 218     Resort Hotel            1          1               2015
# 219     Resort Hotel            1          1               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# ...              ...          ...        ...                ...
# 119119    City Hotel            0         40               2017
# 119122    City Hotel            0         40               2017
# 119123    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 218                  July                        28
# ...

# %%
#This code is for showing the part of the dataframe that the coloumn of agent doesn't have a name
dfi[dfi['agent'].isna()==True]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 6       Resort Hotel            0          0               2015
# 18      Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119124    City Hotel            0          0               2017
# 119151    City Hotel            0          0               2017
# 119166    City Hotel            0          0               2017
# 119215    City Hotel            0          2               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#It is much better to remove the columns of company and agent
dfi=dfi.drop(["agent","company"], axis=1)

# %%
dfi.shape
# Out:
# (119390, 30)

# %%
dfi[dfi['is_canceled'].isna()]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 30 columns]

# %%
dfi[dfi['is_canceled'].isna()==True]['is_canceled']
# Out:
# Series([], Name: is_canceled, dtype: int64)

# %%
#This block is utilized to find NAN values for each column
for j in dfi.columns:
    print('***column of ',j,'***')
    print(dfi[dfi[j].isna()==True][j])
    print('-----------------------------------------')
# Out:
# ***column of  hotel ***
# Series([], Name: hotel, dtype: object)
# -----------------------------------------
# ***column of  is_canceled ***
# Series([], Name: is_canceled, dtype: int64)
# -----------------------------------------
# ***column of  lead_time ***
# Series([], Name: lead_time, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_year ***
# Series([], Name: arrival_date_year, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_month ***
# Series([], Name: arrival_date_month, dtype: object)
# -----------------------------------------
# ***column of  arrival_date_week_number ***
# Series([], Name: arrival_date_week_number, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_day_of_month ***
# Series([], Name: arrival_date_day_of_month, dtype: int64)
# -----------------------------------------
# ***column of  stays_in_weekend_nights ***
# ...

# %%
dfi.loc[40600,'children']=0
dfi.loc[40667,'children']=0
dfi.loc[40679,'children']=0
dfi.loc[41160,'children']=0

# %%
dfi[dfi['children'].isna()==True]['children']
# Out:
# Series([], Name: children, dtype: float64)

# %%
dfi[dfi['country'].isna()==True]['country']
# Out:
# 30        NaN
# 4127      NaN
# 7092      NaN
# 7860      NaN
# 8779      NaN
#          ...
# 65908     NaN
# 65909     NaN
# 65910     NaN
# 80830     NaN
# 101488    NaN
# Name: country, Length: 488, dtype: object

# %%
dfi_cleaned=dfi[dfi['country'].isna()==False]

# %%
for j in dfi_cleaned.columns:
    print('***column of ',j,'***')
    print(dfi_cleaned[dfi_cleaned[j].isna()==True][j])
    print('-----------------------------------------')
# Out:
# ***column of  hotel ***
# Series([], Name: hotel, dtype: object)
# -----------------------------------------
# ***column of  is_canceled ***
# Series([], Name: is_canceled, dtype: int64)
# -----------------------------------------
# ***column of  lead_time ***
# Series([], Name: lead_time, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_year ***
# Series([], Name: arrival_date_year, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_month ***
# Series([], Name: arrival_date_month, dtype: object)
# -----------------------------------------
# ***column of  arrival_date_week_number ***
# Series([], Name: arrival_date_week_number, dtype: int64)
# -----------------------------------------
# ***column of  arrival_date_day_of_month ***
# Series([], Name: arrival_date_day_of_month, dtype: int64)
# -----------------------------------------
# ***column of  stays_in_weekend_nights ***
# ...

# %%
df=dfi_cleaned

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df.to_csv('C:/Users/shaha/Desktop/Springboard/Unit11_Project/Cleaned_data.csv')

# %%
plt.hist(df['is_canceled'])
plt.xlabel('0=Reservation             1=Cancelation')
plt.ylabel('number of reservation or cancelation')
plt.show()

# %%
x=df[df['is_canceled']==0]['arrival_date_month']
y=df[df['is_canceled']==0]['is_canceled']
plt.hist(x)
plt.xlabel('Month of reservation')
plt.ylabel('Number of reservation')
plt.xticks(rotation=45)
plt.show()

# %%
x=df[df['is_canceled']==0]['stays_in_weekend_nights']
plt.hist(x,bins=20)
plt.xlabel('Staying in weekend nights')
plt.ylabel('Number of reservation')
#plt.xticks(rotation=45)
plt.show()

# %%
x=df[df['is_canceled']==0]['stays_in_week_nights']
y=df[df['is_canceled']==0]['stays_in_weekend_nights']
plt.scatter(x,y)
plt.xlabel('stays_in_week_nights')
plt.ylabel('stays_in_weekend_nights')
#plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot('is_canceled', data=df, hue='arrival_date_year')
plt.xlabel('0: Reservation         1: Cancelation')
plt.ylabel('Number of people')
plt.plot()
# Out:
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df['arrival_date_month'].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int64)

# %%
#creating a master database to seperate reservation and canceleation and some important information in terms of date
l=[]
for i in df['arrival_date_year'].unique():
    df_year=df[df['arrival_date_year']==i]
    for j in df['arrival_date_month'].unique():
        df_year_Month=df_year[df_year['arrival_date_month']==j]
        df_year_Month_R=df_year_Month[df_year_Month['is_canceled']==0][['is_canceled','arrival_date_year',
                                                                        'arrival_date_month','stays_in_weekend_nights',
                                                                        'stays_in_week_nights','adults',
                                                                        'assigned_room_type']]
        df_year_Month_C=df_year_Month[df_year_Month['is_canceled']==1][['is_canceled','arrival_date_year',
                                                                        'arrival_date_month','stays_in_weekend_nights',
                                                                        'stays_in_week_nights','adults',
                                                                        'assigned_room_type']]
        l.append(df_year_Month_R)
        l.append(df_year_Month_C)

# %%
lt=list(l[0]['is_canceled'])
for i in l[1]['is_canceled']:
    lt.append(i)

# %%
df1=l[0];df2=l[1];
new_df_July=pd.concat([df1,df2])
df1=l[2];df2=l[3];new_df_A=pd.concat([df1,df2])
df1=l[4];df2=l[5];new_df_S=pd.concat([df1,df2])
df1=l[6];df2=l[7];new_df_O=pd.concat([df1,df2])
df1=l[8];df2=l[9];new_df_N=pd.concat([df1,df2])
df1=l[10];df2=l[11];new_df_D=pd.concat([df1,df2])
df1=l[12];df2=l[13];new_df_Ja=pd.concat([df1,df2])
df1=l[14];df2=l[15];new_df_F=pd.concat([df1,df2])
df1=l[16];df2=l[17];new_df_M=pd.concat([df1,df2])
df1=l[18];df2=l[19];new_df_Ap=pd.concat([df1,df2])
df1=l[20];df2=l[21];new_df_Ma=pd.concat([df1,df2])
df1=l[22];df2=l[23];new_df_J=pd.concat([df1,df2])

# %%
#plt.figure(figsize=(10,10))
fig, ax=plt.subplots(2,3,figsize=(15,10))
sns.countplot('is_canceled',data=new_df_July,ax=ax[0,0])
sns.countplot('is_canceled',data=new_df_A,ax=ax[0,1])
sns.countplot('is_canceled',data=new_df_S,ax=ax[0,2])
sns.countplot('is_canceled',data=new_df_O,ax=ax[1,0])
sns.countplot('is_canceled',data=new_df_N,ax=ax[1,1])
sns.countplot('is_canceled',data=new_df_D,ax=ax[1,2])
plt.show()
print(' Status of reservation from July to December 2015 (There is data for January to June)')
# Out:
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df1=l[24];df2=l[25];
new_df_July=pd.concat([df1,df2])
df1=l[26];df2=l[27];new_df_A=pd.concat([df1,df2])
df1=l[28];df2=l[29];new_df_S=pd.concat([df1,df2])
df1=l[30];df2=l[31];new_df_O=pd.concat([df1,df2])
df1=l[32];df2=l[33];new_df_N=pd.concat([df1,df2])
df1=l[34];df2=l[35];new_df_D=pd.concat([df1,df2])
df1=l[36];df2=l[37];new_df_Ja=pd.concat([df1,df2])
df1=l[38];df2=l[39];new_df_F=pd.concat([df1,df2])
df1=l[40];df2=l[41];new_df_M=pd.concat([df1,df2])
df1=l[42];df2=l[43];new_df_Ap=pd.concat([df1,df2])
df1=l[44];df2=l[45];new_df_Ma=pd.concat([df1,df2])
df1=l[46];df2=l[47];new_df_J=pd.concat([df1,df2])

# %%
fig, ax=plt.subplots(2,6, figsize=(15,10))
sns.countplot('is_canceled',data=new_df_Ja,ax=ax[0,0])
sns.countplot('is_canceled',data=new_df_F,ax=ax[0,1])
sns.countplot('is_canceled',data=new_df_M,ax=ax[0,2])
sns.countplot('is_canceled',data=new_df_Ap,ax=ax[0,3])
sns.countplot('is_canceled',data=new_df_Ma,ax=ax[0,4])
sns.countplot('is_canceled',data=new_df_J,ax=ax[0,5])
sns.countplot('is_canceled',data=new_df_July,ax=ax[1,0])
sns.countplot('is_canceled',data=new_df_A,ax=ax[1,1])
sns.countplot('is_canceled',data=new_df_S,ax=ax[1,2])
sns.countplot('is_canceled',data=new_df_O,ax=ax[1,3])
sns.countplot('is_canceled',data=new_df_N,ax=ax[1,4])
sns.countplot('is_canceled',data=new_df_D,ax=ax[1,5])
plt.show()
print('   Status of reservation from January to December 2016')
# Out:
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df1=l[48];df2=l[49];
new_df_July=pd.concat([df1,df2])
df1=l[50];df2=l[51];new_df_A=pd.concat([df1,df2])
df1=l[52];df2=l[53];new_df_S=pd.concat([df1,df2])
df1=l[54];df2=l[55];new_df_O=pd.concat([df1,df2])
df1=l[56];df2=l[57];new_df_N=pd.concat([df1,df2])
df1=l[58];df2=l[59];new_df_D=pd.concat([df1,df2])
df1=l[60];df2=l[61];new_df_Ja=pd.concat([df1,df2])
df1=l[62];df2=l[63];new_df_F=pd.concat([df1,df2])
df1=l[64];df2=l[65];new_df_M=pd.concat([df1,df2])
df1=l[66];df2=l[67];new_df_Ap=pd.concat([df1,df2])
df1=l[68];df2=l[69];new_df_Ma=pd.concat([df1,df2])
df1=l[70];df2=l[71];new_df_J=pd.concat([df1,df2])

# %%
#plt.figure(figsize=(1,8))
fig, ax=plt.subplots(2,4, figsize=(15,10))
sns.countplot('is_canceled',data=new_df_Ja,ax=ax[0,0])
sns.countplot('is_canceled',data=new_df_F,ax=ax[0,1])
sns.countplot('is_canceled',data=new_df_M,ax=ax[0,2])
sns.countplot('is_canceled',data=new_df_Ap,ax=ax[0,3])
sns.countplot('is_canceled',data=new_df_Ma,ax=ax[1,0])
sns.countplot('is_canceled',data=new_df_J,ax=ax[1,1])
sns.countplot('is_canceled',data=new_df_July,ax=ax[1,2])
sns.countplot('is_canceled',data=new_df_A,ax=ax[1,3])
plt.show()
print('Status of reservation from January to August 2017 (There is no information from Septemebr to December)')
# Out:
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shaha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df[df['is_canceled']==0]['assigned_room_type'], data=df)
plt.xlabel('Room type reservation from 2015 to 2017')
plt.ylabel('Number of reservations')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df[df['is_canceled']==0]['assigned_room_type'], data=df, hue='arrival_date_year')
plt.xlabel('Classified room type reservation from 2015 to 2017')
plt.ylabel('Number of reservations')
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x=df[df['is_canceled']==0]['stays_in_week_nights'],y=df[df['is_canceled']==0]['stays_in_weekend_nights'],
                data=df, hue='arrival_date_year')
plt.xlabel('staying_in_week_nights')
plt.ylabel('staying_in_weekend_nights')
#plt.xticks(rotation=45)
plt.show()

# %%
#Comparison of staying_in_weekend_nights versus staying_in_week_nights
plt.figure(figsize=(7,7))
sns.regplot(x=df[df['is_canceled']==0]['stays_in_week_nights'],y=df[df['is_canceled']==0]['stays_in_weekend_nights'], data=df)
plt.xlabel('staying_in_week_nights')
plt.ylabel('staying_in_weekend_nights')
plt.show()

# %%
sns.set()
plt.hist(df[df['is_canceled']==0]['lead_time'])
plt.xlabel('lead time')
plt.ylabel('Number of people')
plt.show()

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
#Bootstrapping and showing normal distribution for two lists of "stays_in_week_nights" and "stays_in_weekend_nights"
lm_a=[]
lm_b=[]
list_a=df['stays_in_week_nights']
list_b=df['stays_in_weekend_nights']
for i in range(10000):
    sample_a=np.random.choice(list_a,len(list_a))
    sample_b=np.random.choice(list_b,len(list_b))
    mean_a=np.mean(sample_a)
    mean_b=np.mean(sample_b)
    lm_a.append(mean_a)
    lm_b.append(mean_b)

# %%
plt.hist(lm_a,bins=30)
plt.xlabel('Average of staying_in_week_nights')
plt.ylabel('Dsitribution')
plt.show()

# %%
plt.hist(lm_b,bins=30)
plt.xlabel('Average of staying_in_weekend_nights')
plt.ylabel('Dsitribution')
plt.show()

# %%
#Emprical cumilative distribution function
x=np.sort(list_a)
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y, marker='.', linestyle='none')
_=plt.xlabel('Percentage of staying_in_week_nights')
_=plt.ylabel('ECDF')
plt.margins(0.02)
plt.show()

# %%
x=np.sort(list_b)
y=np.arange(1,len(x)+1)/len(x)
_=plt.plot(x,y, marker='.', linestyle='none')
_=plt.xlabel('Percentage of staying_in_weekend_nights')
_=plt.ylabel('ECDF')
plt.margins(0.02)
plt.show()

# %%
Diff_observed=np.mean(list_a)-np.mean(list_b)

# %%
#Test statistics and null hypothesis
bs_replicates=[]
for i in range(10000):
    sample_a=np.random.choice(list_a,len(list_a))
    sample_b=np.random.choice(list_b,len(list_b))
    sample_difference=np.mean(sample_a)-np.mean(sample_b)
    bs_replicates.append(sample_difference)

# %%
bs_replicates=np.array(bs_replicates)

# %%
p=np.sum(bs_replicates>=Diff_observed)/10000
print(p)
# Out:
# 0.4928
